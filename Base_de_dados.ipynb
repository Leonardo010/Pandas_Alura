# %% [markdown]
# # Relatório de Análises I

# %% [markdown]
# ## Importando Base de Dados

# %%
# !pip install requests
# !pip install bs4
# Out:
# ...
#      -------------------------------------- 62.8/62.8 kB 674.4 kB/s eta 0:00:00
# ...
#      -------------------------------------- 140.4/140.4 kB 1.4 MB/s eta 0:00:00
# ...
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# ...
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=ac1c3c2d6f15ab4b2cf0f6ab5f3b96d46d8713ace42e031f5e43b1c2350ee4c8
#   Stored in directory: c:\users\pichau\appdata\local\pip\cache\wheels\25\42\45\b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...

# %%
import pandas as pd

# %% [markdown]
# MUDANDO SEPARADOR

# %%
dados = pd.read_csv('Data/aluguel.csv', sep=';')

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %% [markdown]
# ## Informações Gerais

# %%
variables = pd.DataFrame(dados.dtypes, columns = ['Tipo de Dado'])
variables.columns.name = 'Variáveis'
variables
# Out:
# Variáveis  Tipo de Dado
# Tipo             object
# Bairro           object
# Quartos           int64
# Vagas             int64
# Suites            int64
# Area              int64
# Valor           float64
# Condominio      float64
# IPTU            float64

# %%
print(f'A base de Dados apresenta {dados.shape[0]} imóveis registrados e {dados.shape[1]} variáveis')
# Out:
# A base de Dados apresenta 32960 imóveis registrados e 9 variáveis
