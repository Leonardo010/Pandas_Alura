# %%
import pandas as pd

# %%
dataset = pd.read_csv(r'C:\Users\PICHAU\PycharmProjects\Pandas\db.csv', sep=';', index_col=0)

# %%
for item in dataset:
    print(item)
# Out:
# Motor
# Ano
# Quilometragem
# Zero_km
# Acessórios
# Valor

# %%
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
#                                                               Acessórios  \
# Nome
# Jetta Variant          ['Rodas de liga', 'Travas elétricas', 'Piloto ...
# Passat                 ['Central multimídia', 'Teto panorâmico', 'Fre...
# Crossfox               ['Piloto automático', 'Controle de estabilidad...
# DS5                    ['Travas elétricas', '4 X 4', 'Vidros elétrico...
# Aston Martin DB4       ['Rodas de liga', '4 X 4', 'Central multimídia...
# ...                                                                  ...
# Phantom 2013           ['Controle de estabilidade', 'Piloto automátic...
# Cadillac Ciel concept  ['Bancos de couro', 'Painel digital', 'Sensor ...
# Classe GLK             ['Rodas de liga', 'Controle de tração', 'Câmbi...
# Aston Martin DB5       ['Ar condicionado', '4 X 4', 'Câmbio automátic...
# Macan                  ['Central multimídia', 'Teto panorâmico', 'Vid...
#
#                            Valor
# Nome
# Jetta Variant           88078.64
# Passat                 106161.94
# Crossfox                72832.16
# DS5                    124549.07
# Aston Martin DB4        92612.10
# ...                          ...
# Phantom 2013            51759.58
# Cadillac Ciel concept   51667.06
# Classe GLK              68934.03
# Aston Martin DB5       122110.90
# Macan                   90381.47
#
# [258 rows x 6 columns]

# %%
for index, row in dataset.iterrows():
    if (2019 - row['Ano']) != 0:
        dataset.loc[index, 'Km_media'] = row['Quilometragem']/(2019-row['Ano'])
    else:
        dataset.loc[index, 'Km_media'] = 0

# %%
dataset.isna()
# Out:
#                        Motor    Ano  Quilometragem  Zero_km  Acessórios  \
# Nome
# Jetta Variant          False  False          False    False       False
# Passat                 False  False          False    False       False
# Crossfox               False  False          False    False       False
# DS5                    False  False           True    False       False
# Aston Martin DB4       False  False          False    False       False
# ...                      ...    ...            ...      ...         ...
# Phantom 2013           False  False          False    False       False
# Cadillac Ciel concept  False  False          False    False       False
# Classe GLK             False  False          False    False       False
# Aston Martin DB5       False  False          False    False       False
# Macan                  False  False          False    False       False
#
#                        Valor  Km_media
# Nome
# Jetta Variant          False     False
# Passat                 False     False
# Crossfox               False     False
# DS5                    False     False
# Aston Martin DB4       False     False
# ...                      ...       ...
# Phantom 2013           False     False
# Cadillac Ciel concept  False     False
# Classe GLK             False     False
# Aston Martin DB5       False     False
# Macan                  False     False
#
# [258 rows x 7 columns]
